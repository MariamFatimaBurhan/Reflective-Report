# %% [markdown]
# Mariam Fatima Burhan 47578548

# %% [markdown]
# # Reflective Report

# %% [markdown]
# # Report the process of solving problems and learning to use notebooks

# %% [markdown]
# Firstly, we came across the platform of Anaconda software, which allowed us to use Jupyter Notebook. It uses your web browser to open a new notebook and the language to use. We chose Python language for this course to solve different problems.
#
# At first, we learnt the basics of the Python language such a S
# •	String Manipulation
# •	Controlling Structures
# •	Plotting Graph through seaborn which is a Python data visualization library such as Line, Bar, Histogram, Count plot, Scatter plot, Heat map.
# •	Lists and Dictionaries
# •	Pandas Dataframe
#
# Furthermore, we were given different datasets on which we had to apply different functions such as:
# •	cleaning the data
# •	data pre-processing
# •	Data normalisation
# •	checking unique data
# •	checking the size of data, mean, median and standard deviation value of selected columns.
#
# Moreover, we were also instructed upon how to find outliers in data, analyse them through using Boxplot and how to remove them. We were also asked to calculate Linear Regression with more than one variable of the dataset. We were also instructed to split up the data into two sets i.e., training and test data through which we built a model on training data and test it on the test data.
# We also used Model Evaluation in which we trained a Logistic Regression model via cross-validation to determine the hyper parameters and model’s performance. We also learnt about different data classifiers such as KNN Classifier, Multinomial Naïve Bayes and Naïve Bayes Classifier and compare their performance according to their mean and standard deviation scores. We also used clustering techniques like K-Means clustering and Hierchical clustering and calculated the accuracy scores of the data through it, checked how number of clusters can make it easier to distinguish them and then defined each cluster in terms of movie profile.
# ![image.png](attachment:image.png)

# %% [markdown]
# # How have you progressed from the start of the unit, what are you interested in doing with this in the future?

# %% [markdown]
# At first, since I was new to programming and data analysis, I had a very little idea about different programming languages such as Python. However, after attending the practical workshops and exploring different functions of Python, I gradually learnt how can we manipulate data to make it more useful. Through the portfolios exercise,  I was able to use my class knowledge and implement on it and actually scored better than I expected. Therefore, I would use my learning from this course for my other advanced data science courses and also at my workplace since I aim to become a business analyst in future. With this knowledge, I can actually apply to any local company’s data and making it more meaningful for them through all the analytical techniques I have learnt, in order to stand out among others.

# %% [markdown]
# # Discussion points Based on Portfolio 4

# %% [markdown]
# ### Why did you choose the dataset you have used for your portfolio?

# %% [markdown]
# I have chosen “IMDB top 250 Movies” dataset for this portfolio. This data includes information such as:
# - movie rank
# - title
# - year of release
# - IMDB votes
# - IMDB rating
# -  movie duration
# - genre
# - storyline
# - review content
#
# The reason for this choice was that nowadays the younger generation judge the selection of  movies they want to see based on their ranking and  overall ratings. IMDB is a popular platform for this purpose, and it has got numerous movies that belongs to different genres and eras. Therefore, anyone who wants to make a movie can take advantage from this. For instance, through the analysis of movie rankings we can identify the trends of the top movies or genres or through the analysis of movie ratings, we can identify high rated movies, comparison of ratings of different movies and evaluating the correlation between the ratings and genre or ranking.

# %% [markdown]
# ### Can you well explain the insights or conclusion you draw from your study? Is the result consistent with your intuitive expectation?

# %% [markdown]
# From this study, we concluded that there is just one missing value in whole data set. After processing the genre of the movies, we found out that there are 104 unique genres in the data. We performed linear regression on the data  taking movie rank as out input (X) and  movie rating(y) as output and found out that Mean Squared Error is very much lower which means the forecast is closer to the actual. By calculating the Root mean squared error (RMSE) we concluded that the model can predict the data accurately. We also calculated the number of reviews a movie has receive to influence the movie rating and applied Linear Regression on it, and found out that our model is relatively accurate since the value of it was close to 0. Lastly, we used two classifiers i.e., KNN classifier and Naïve Bayes classifier to calculate accuracy mean and standard deviation and found out that the performance of KNN is better than Naïve Bayes since the mean of KNN higher than Naïve Bayes i.e., 93% which means its more accurate. However, the std of KNN is higher than that of Naïve Bayes, therefore KNN classifier can be less consistent across different test datasets.
